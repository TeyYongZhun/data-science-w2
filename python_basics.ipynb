# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
x=5
print(x)
print("Value of x is: " , x)
print(type(x))

y=3.142
print(y)
print(type(y))
# Out:
# 5
# Value of x is:  5
# <class 'int'>
# 3.142
# <class 'float'>
